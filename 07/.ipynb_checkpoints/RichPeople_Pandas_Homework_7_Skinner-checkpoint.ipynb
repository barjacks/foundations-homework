# %%
import pandas as pd

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_excel("Billionaire Characteristics Database/richpeople.xlsx")

# %%
# !pip install xlrd

# %%
df.head(3)
# Out:
#    year                         name  rank    citizenship countrycode  \
# 0  2001          A Jerrold Perenchio   151  United States         USA
# 1  2014         A. Jerrold Perenchio   663  United States         USA
# 2  2001  Abdul Al Rahman  Al Jeraisy   336   Saudi Arabia         SAU
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 0                3.0  self-made            executive   male  70.0   ...
# 1                2.6  self-made            executive   male  83.0   ...
# 2                1.5  self-made  founder non-finance   male   NaN   ...
#
#      relationshiptocompany foundingdate  gdpcurrentus         sourceofwealth  \
# 0  former chairman and CEO       1955.0  1.062180e+13                    NaN
# 1  former chairman and CEO       1955.0           NaN  television, Univision
# 2                  founder       1956.0  1.830120e+11                    NaN
#
#                                             notes  notes2  \
# ...

# %%
df.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
recent = df[df['year'] == 2014]
recent.head(3)
# Out:
#    year                          name  rank           citizenship countrycode  \
# 1  2014          A. Jerrold Perenchio   663         United States         USA
# 5  2014            Abdulla Al Futtaim   687  United Arab Emirates         ARE
# 6  2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates         ARE
#
#    networthusbillion   selfmade typeofwealth gender   age   ...     \
# 1                2.6  self-made    executive   male  83.0   ...
# 5                2.5  inherited    inherited   male   NaN   ...
# 6                4.8  inherited    inherited   male   NaN   ...
#
#      relationshiptocompany foundingdate gdpcurrentus  \
# 1  former chairman and CEO       1955.0          NaN
# 5                 relation       1930.0          NaN
# 6                 relation       1960.0          NaN
#
#               sourceofwealth                                           notes  \
# 1      television, Univision  represented Marlon Brando and Elizabeth Taylor
# ...

# %% [markdown]
# *1. What country are most billionaires from?

# %%
recent['countrycode'].value_counts().head()
#df['animal'].value_counts()
# Out:
# USA    499
# CHN    152
# RUS    111
# DEU     85
# BRA     65
# Name: countrycode, dtype: int64

# %% [markdown]
# *2. Display the billionaires from Switzerland.

# %%
Swiss_billionaires = recent[recent['countrycode'] == 'CHE']
Swiss_billionaires.head(3)
# Out:
#      year                    name  rank  citizenship countrycode  \
# 257  2014  Benjamin de Rothschild   869  Switzerland         CHE
# 609  2014      Edgar de Picciotto  1078  Switzerland         CHE
# 676  2014      Ernesto Bertarelli    92  Switzerland         CHE
#
#      networthusbillion   selfmade       typeofwealth gender   age  \
# 257                2.0  inherited          inherited   male  50.0
# 609                1.7  self-made  self-made finance   male  84.0
# 676               12.0  inherited          inherited   male  48.0
#
#                            ...                         relationshiptocompany  \
# 257                        ...                                      relation
# 609                        ...                                       founder
# 676                        ...                                      relation
#
#     foundingdate gdpcurrentus        sourceofwealth  \
# 257       1953.0          NaN               banking
# ...

# %% [markdown]
# *3. Who is the youngest billionaire?

# %%
recent.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
recent.sort_values(by='age').head(5)
# Out:
#       year                 name  rank    citizenship countrycode  \
# 1838  2014          Perenna Kei  1284      Hong Kong         HKG
# 605   2014     Dustin Moskovitz   202  United States         USA
# 1586  2014      Mark Zuckerberg    21  United States         USA
# 189   2014  Anton Kathrein, Jr.  1270        Germany         DEU
# 602   2014         Drew Houston  1372  United States         USA
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 1838                1.3  inherited            inherited  female  24.0
# 605                 6.8  self-made  founder non-finance    male  29.0
# 1586               28.5  self-made  founder non-finance    male  29.0
# 189                 1.4  inherited            inherited    male  29.0
# 602                 1.2  self-made  founder non-finance    male  30.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  sourceofwealth  \
# ...

# %% [markdown]
# *4. And the oldest billionaires?

# %%
recent.sort_values(by='age', ascending = False).head(5)
# Out:
#       year                    name  rank    citizenship countrycode  \
# 516   2014  David Rockefeller, Sr.   580  United States         USA
# 1277  2014           Karl Wlaschek   305        Austria         AUT
# 1328  2014          Kirk Kerkorian   328  United States         USA
# 921   2014           Henry Hillman   687  United States         USA
# 666   2014      Erika Pohl-Stroher  1154        Germany         DEU
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 516                 2.9  inherited            inherited    male  98.0
# 1277                4.8  self-made  founder non-finance    male  96.0
# 1328                4.5  self-made    self-made finance    male  96.0
# 921                 2.5  inherited            inherited    male  95.0
# 666                 1.5  inherited            inherited  female  95.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 516    ...                 relation       1870.0          NaN
# ...

# %% [markdown]
# *4. And the richest billionaire in the world?

# %%
recent.sort_values(by='networthusbillion', ascending = False).head(5)
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
#
#       networthusbillion   selfmade              typeofwealth gender   age  \
# 284                76.0  self-made       founder non-finance   male  58.0
# 348                72.0  self-made  privatized and resources   male  74.0
# 124                64.0  self-made       founder non-finance   male  77.0
# 2491               58.2  self-made       founder non-finance   male  83.0
# 1377               48.0  self-made       founder non-finance   male  69.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 284    ...                  founder       1975.0          NaN
# ...

# %% [markdown]
# *5. Average wealth by nation?

# %%
recent.groupby(['countrycode'])['networthusbillion'].mean().sort_values(ascending = False).head(15)
# Out:
# countrycode
# MEX    8.931250
# NGA    8.325000
# COL    7.650000
# SAU    7.000000
# SWE    6.142105
# FRA    5.472093
# GEO    5.200000
# IRL    5.100000
# CYP    4.925000
# NZL    4.900000
# HKG    4.748889
# DEU    4.722353
# ESP    4.715385
# USA    4.654108
# ITA    4.517143
# Name: networthusbillion, dtype: float64

# %% [markdown]
# *Where is the oldest money?

# %%
recent.groupby(['generationofinheritance']).count()
# Out:
#                             year  name  rank  citizenship  countrycode  \
# generationofinheritance
# 0                           1151  1151  1151         1151         1151
# Fifth generation or longer    15    15    15           15           15
# Fourth generation             33    33    33           33           33
# Third generation             100   100   100          100          100
# inherited from father        316   316   316          316          316
# spouse or widow               38    38    38           38           38
#
#                             networthusbillion  selfmade  typeofwealth  gender  \
# generationofinheritance
# 0                                        1151      1149          1149    1151
# Fifth generation or longer                 15        15            15      15
# Fourth generation                          33        33            33      33
# Third generation                          100       100           100     100
# ...

# %%
recent[recent['generationofinheritance'] == 'Fith generation or longer']

df[df['POS'] == 'G']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-faf0cb14a3a6> in <module>()
# ...
