# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("Billionaire Characteristics Database/richpeople.xlsx")

# %%
recent = df[df['year'] == 2014]

# %%
recent['countrycode'].value_counts().head(5) #499 many bil
# Out:
# USA    499
# CHN    152
# RUS    111
# DEU     85
# BRA     65
# Name: countrycode, dtype: int64

# %%
recent.sort_values(by='networthusbillion', ascending=False).head(5)
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
#
#       networthusbillion   selfmade              typeofwealth gender   age  \
# 284                76.0  self-made       founder non-finance   male  58.0
# 348                72.0  self-made  privatized and resources   male  74.0
# 124                64.0  self-made       founder non-finance   male  77.0
# 2491               58.2  self-made       founder non-finance   male  83.0
# 1377               48.0  self-made       founder non-finance   male  69.0
#
#        ...    relationshiptocompany foundingdate gdpcurrentus  \
# 284    ...                  founder       1975.0          NaN
# ...

# %%
recent[recent['rank'] == 1565]
# Out:
#       year                      name  rank     citizenship countrycode  \
# 56    2014           Alberto Alcocer  1565           Spain         ESP
# 81    2014             Alexander Vik  1565          Norway         NOR
# 129   2014                   An Kang  1565           China         CHN
# 145   2014  Andrea Reimann-Ciardelli  1565   United States         USA
# 164   2014           Andrew Gotianun  1565     Philippines         PHL
# 171   2014            Angela Bennett  1565       Australia         AUS
# 178   2014             Anne Beaufour  1565          France         FRA
# 234   2014               B.R. Shetty  1565           India         IND
# 261   2014               Bent Jensen  1565         Denmark         DEN
# 296   2014               Boris Mints  1565          Russia         RUS
# 302   2014             Brian Higgins  1565   United States         USA
# 320   2014             C. James Koch  1565   United States         USA
# ...

# %%
recent['networthusbillion'].describe()
# Out:
# count    1653.000000
# mean        3.904658
# std         5.748520
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64

# %%
recent[recent['gender'] == 'male'].describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          year         rank  networthusbillion          age        north  \
# count  1473.0  1473.000000        1473.000000  1424.000000  1473.000000
# mean   2014.0   810.380855           3.902716    63.427669     0.556687
# std       0.0   463.014514           5.801227    13.025046     0.496945
# min    2014.0     1.000000           1.000000    29.000000     0.000000
# 25%    2014.0   408.000000           1.400000          NaN     0.000000
# 50%    2014.0   828.000000           2.100000          NaN     1.000000
# 75%    2014.0  1210.000000           3.700000          NaN     1.000000
# max    2014.0  1565.000000          76.000000    98.000000     1.000000
#
#        politicalconnection      founder  foundingdate  gdpcurrentus
# count                 50.0  1473.000000   1461.000000           0.0
# ...

# %%
recent.groupby(recent['gender']).describe()
# Out:
# /usr/local/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                       age      founder  foundingdate  gdpcurrentus  \
# gender
# female count   166.000000   180.000000    180.000000           0.0
#        mean     62.608434     0.161111   1939.450000           NaN
#        std      14.087938     0.368659     43.277625           NaN
#        min      24.000000     0.000000   1670.000000           NaN
#        25%            NaN     0.000000   1923.000000           NaN
#        50%            NaN     0.000000   1946.000000           NaN
#        75%            NaN     0.000000   1967.250000           NaN
#        max      95.000000     1.000000   2007.000000           NaN
# male   count  1424.000000  1473.000000   1461.000000           0.0
#        mean     63.427669     0.556687   1966.109514           NaN
#        std      13.025046     0.496945     36.338444           NaN
# ...

# %% [markdown]
# #Adding up wealth by country

# %%
recent.groupby('countrycode')['networthusbillion'].sum().sort_values(ascending=False).head(10)
# Out:
# countrycode
# USA    2322.4
# RUS     422.5
# DEU     401.4
# CHN     375.8
# FRA     235.3
# HKG     213.7
# BRA     192.2
# IND     191.9
# ITA     158.1
# GBR     152.0
# Name: networthusbillion, dtype: float64

# %% [markdown]
# #Industries

# %%
recent['industry'].value_counts()
# Out:
# Consumer                           291
# Real Estate                        190
# Retail, Restaurant                 174
# Diversified financial              132
# Technology-Computer                131
# Money Management                   122
# Media                              104
# Energy                              87
# Non-consumer industrial             83
# Technology-Medical                  78
# Mining and metals                   68
# Constrution                         61
# Other                               59
# Hedge funds                         43
# Private equity/leveraged buyout     18
# 0                                    6
# Venture Capital                      5
# Name: industry, dtype: int64

# %% [markdown]
# #whats the total amount of billionaire money from each industry

# %%
x = recent.groupby('industry')['networthusbillion'].sum().sort_values(ascending = False)

# %%
x.plot(kind='barh', x='name', y='networthusbillion', legend = False)

# %%
# YOung and rich and cool: Billionaires under 35:
sorted_young_bils = recent[recent['age'] < 35].sort_values(by='networthusbillion', ascending = True)
#recent[recent['age'] < 40].plot(kind='barh', x='name', y='networthusbillion')
sorted_young_bils.plot(kind='barh', x='name', y='networthusbillion', legend = False)

# %%
plt.style.use("ggplot")
# %matplotlib inline
